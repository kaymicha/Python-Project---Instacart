# %% [markdown]
# # 4.8 - Grouping & Aggregating Variables - Contents

# %% [markdown]
# 1. Find and Replace
# 2. Finding aggregated means
# 3. Creating Loyalty Flags
# 4. Creating Spending Flags

# %% [markdown]
# ## Step 1 - Importing libraries and dataframes

# %%
# Import Libraries
import pandas as pd
import numpy as np
import os

# %%
# Defining path
path = r'C:\Users\kaymi\OneDrive\Documents\05-2023-Instacart Basket Analysis'

# %%
# Import ords_prods_merged
ords_prods_merge =  pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data','orders_products_merged_updated.pkl'))

# %%
# Check columns
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#   days_since_last_order  product_id  add_to_cart_order  reordered  \
# 0           first order         196                  1          0
# 1                  15.0         196                  1          1
# 2                  21.0         196                  1          1
# 3                  29.0         196                  1          1
# 4                  28.0         196                  1          1
#
#    Unnamed: 0_y product_name  aisle_id  department_id  prices _merge  \
# 0           195         Soda        77              7     9.0   both
# 1           195         Soda        77              7     9.0   both
# 2           195         Soda        77              7     9.0   both
# 3           195         Soda        77              7     9.0   both
# 4           195         Soda        77              7     9.0   both
#
#    price_range_loc    price_range_loc     busiest_day     busiest_days  \
# 0              NaN  Mid-range product  Regularly busy   Regularly busy
# 1              NaN  Mid-range product  Regularly busy  Least busy days
# 2              NaN  Mid-range product  Regularly busy  Least busy days
# 3              NaN  Mid-range product      Least busy  Least busy days
# 4              NaN  Mid-range product      Least busy  Least busy days
#
#   busiest_period_of_day
# 0        Average orders
# 1        Average orders
# 2           Most orders
# 3        Average orders
# 4           Most orders

# %%
# Find and replace "first order" with 0 in "days since last order" column
ords_prods_merge['days_since_last_order'].replace('first order', None, inplace=True)

# %%
#Check column data type
ords_prods_merge['days_since_last_order'].dtype
# Out:
# dtype('O')

# %%
#Change data type to number
ords_prods_merge['days_since_last_order'] = ords_prods_merge['days_since_last_order'].astype('float')

# %%
# Check data type
ords_prods_merge['days_since_last_order'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# ## Step 2 - Find aggregated mean of entire dataframe

# %%
# Group by Department ID
ords_prods_merge.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.457687
# 2                17.277920
# 3                17.179756
# 4                17.811403
# 5                15.213779
# 6                16.439806
# 7                17.225773
# 8                15.340520
# 9                15.895474
# 10               20.197148
# 11               16.170828
# 12               15.887622
# 13               16.583304
# 14               16.757377
# 15               16.165037
# 16               17.663250
# 17               15.694469
# 18               19.310397
# 19               17.177343
# 20               16.473447
# 21               22.902379

# %% [markdown]
# ## Step 3 - Analyze the results - compare to those of the subset

# %% [markdown]
# #### In the subset, only a handful of departments were displayed due to the limited number of rows pulled. On average, the mean of each department ID in the entire dataframe is lower than that of the subset

# %% [markdown]
# ## Step 4 - Follow the Exercise instructions for creating a loyalty flag

# %%
# split the data into groups based on user_id column, apply the transform() function on the "order_number" column, and create a new max_order column
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
# Check column was created
ords_prods_merge.head(15)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2398795        1             2                   3                  7
# 2     473747        1             3                   3                 12
# 3    2254736        1             4                   4                  7
# 4     431534        1             5                   4                 15
# 5    3367565        1             6                   2                  7
# 6     550135        1             7                   1                  9
# 7    3108588        1             8                   1                 14
# 8    2295261        1             9                   1                 16
# 9    2550362        1            10                   4                  8
# 10   2968173       15            15                   1                  9
# 11   1870022       15            17                   2                 16
# 12   1911383       15            18                   2                 11
# 13   2715276       15            21                   1                  9
# 14    487368       15            22                   1                 10
#
#     days_since_last_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
# 5                    19.0         196                  1          1
# 6                    20.0         196                  1          1
# 7                    14.0         196                  2          1
# 8                     0.0         196                  4          1
# 9                    30.0         196                  1          1
# 10                    7.0         196                  2          0
# 11                    8.0         196                  6          1
# 12                    7.0         196                  1          1
# 13                    7.0         196                  1          1
# 14                   14.0         196                  1          1
#
#     Unnamed: 0_y  ... aisle_id  department_id  prices  _merge  \
# 0            195  ...       77              7     9.0    both
# 1            195  ...       77              7     9.0    both
# 2            195  ...       77              7     9.0    both
# 3            195  ...       77              7     9.0    both
# 4            195  ...       77              7     9.0    both
# 5            195  ...       77              7     9.0    both
# 6            195  ...       77              7     9.0    both
# 7            195  ...       77              7     9.0    both
# 8            195  ...       77              7     9.0    both
# 9            195  ...       77              7     9.0    both
# 10           195  ...       77              7     9.0    both
# 11           195  ...       77              7     9.0    both
# 12           195  ...       77              7     9.0    both
# 13           195  ...       77              7     9.0    both
# 14           195  ...       77              7     9.0    both
#
#     price_range_loc    price_range_loc     busiest_day     busiest_days  \
# 0               NaN  Mid-range product  Regularly busy   Regularly busy
# 1               NaN  Mid-range product  Regularly busy  Least busy days
# 2               NaN  Mid-range product  Regularly busy  Least busy days
# 3               NaN  Mid-range product      Least busy  Least busy days
# 4               NaN  Mid-range product      Least busy  Least busy days
# 5               NaN  Mid-range product  Regularly busy   Regularly busy
# 6               NaN  Mid-range product  Regularly busy     Busiest days
# 7               NaN  Mid-range product  Regularly busy     Busiest days
# 8               NaN  Mid-range product  Regularly busy     Busiest days
# 9               NaN  Mid-range product      Least busy  Least busy days
# 10              NaN  Mid-range product  Regularly busy     Busiest days
# 11              NaN  Mid-range product  Regularly busy   Regularly busy
# 12              NaN  Mid-range product  Regularly busy   Regularly busy
# 13              NaN  Mid-range product  Regularly busy     Busiest days
# 14              NaN  Mid-range product  Regularly busy     Busiest days
#
#    busiest_period_of_day max_order
# 0         Average orders        10
# 1         Average orders        10
# 2            Most orders        10
# 3         Average orders        10
# 4            Most orders        10
# 5         Average orders        10
# 6            Most orders        10
# 7            Most orders        10
# 8            Most orders        10
# 9         Average orders        10
# 10           Most orders        22
# 11           Most orders        22
# 12           Most orders        22
# 13           Most orders        22
# 14           Most orders        22
#
# [15 rows x 21 columns]

# %%
# Derive columns with loc()
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
# Check value counts
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15891077
# Loyal customer      10293737
# New customer         6249398
# Name: loyalty_flag, dtype: int64

# %% [markdown]
# ## Step 5 - Use loyalty flag for analysis

# %%
#Check basic statistics
ords_prods_merge.groupby('loyalty_flag').agg({'prices': ['mean', 'min', 'max']})
# Out:
#                     prices
#                       mean  min   max
# loyalty_flag
# Loyal customer    7.778412  1.0  25.0
# New customer      7.805500  1.0  25.0
# Regular customer  7.802850  1.0  25.0

# %% [markdown]
# ## Step 6 - Create a spending flag based on average price of orders per user

# %%
#Group data on user_id column, apply the transform() function on the "prices" column, and create a new spending column
ords_prods_merge['average_price'] = ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)

# %%
# Derive columns with loc()
ords_prods_merge.loc[ords_prods_merge['average_price'] >= 10, 'spending_flag'] = 'High Spender'

# %%
ords_prods_merge.loc[ords_prods_merge['average_price'] < 10, 'spending_flag'] = 'Low Spender'

# %%
# Check value counts
ords_prods_merge['spending_flag'].value_counts(dropna = False)
# Out:
# Low Spender     32313511
# High Spender      120701
# Name: spending_flag, dtype: int64

# %%
# Return only columns desired
ords_prods_merge[['user_id', 'spending_flag', 'prices']].head(20)
# Out:
#     user_id spending_flag  prices
# 0         1   Low Spender     9.0
# 1         1   Low Spender     9.0
# 2         1   Low Spender     9.0
# 3         1   Low Spender     9.0
# 4         1   Low Spender     9.0
# 5         1   Low Spender     9.0
# 6         1   Low Spender     9.0
# 7         1   Low Spender     9.0
# 8         1   Low Spender     9.0
# 9         1   Low Spender     9.0
# 10       15   Low Spender     9.0
# 11       15   Low Spender     9.0
# 12       15   Low Spender     9.0
# 13       15   Low Spender     9.0
# 14       15   Low Spender     9.0
# 15       19   Low Spender     9.0
# 16       19   Low Spender     9.0
# 17       19   Low Spender     9.0
# 18       21   Low Spender     9.0
# 19       31   Low Spender     9.0

# %% [markdown]
# ## Step 7 - Determine Frequent vs Non-Frequent Customers

# %%
ords_prods_merge['median_prior_orders'] = ords_prods_merge.groupby(['user_id'])['days_since_last_order'].transform(np.median)

# %%
# Check column was created
ords_prods_merge.head(60)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2398795        1             2                   3                  7
# 2     473747        1             3                   3                 12
# 3    2254736        1             4                   4                  7
# 4     431534        1             5                   4                 15
# 5    3367565        1             6                   2                  7
# 6     550135        1             7                   1                  9
# 7    3108588        1             8                   1                 14
# 8    2295261        1             9                   1                 16
# 9    2550362        1            10                   4                  8
# 10   2968173       15            15                   1                  9
# 11   1870022       15            17                   2                 16
# 12   1911383       15            18                   2                 11
# 13   2715276       15            21                   1                  9
# 14    487368       15            22                   1                 10
# 15   2293453       19             2                   5                 14
# 16   1973799       19             5                   6                 12
# 17    532817       19             7                   4                 17
# 18   1573906       21            10                   3                 10
# 19   1593000       31            10                   3                  8
# 20   2231262       31            17                   3                 11
# 21   2580647       43             6                   4                 16
# 22   2187180       43             9                   4                 12
# 23   2497897       52             1                   1                  9
# 24   1318871       52             2                   1                 10
# 25   1261384       52             3                   1                 10
# 26    580568       52             5                   2                 10
# 27   2428073       52             7                   2                  7
# 28    342306       52             9                   1                 11
# 29   1520353       52            10                   2                 10
# 30   2542086       52            11                   2                  9
# 31    944694       52            12                   1                 16
# 32   1268191       52            15                   2                 11
# 33   1122089       52            17                   2                 10
# 34   1498922       52            18                   2                 10
# 35    180919       52            19                   3                  8
# 36   2695875       52            21                   5                 10
# 37   3205960       67             1                   3                 11
# 38    970922       67             2                   1                 15
# 39    596585       67             3                   1                 13
# 40   2037087       67             4                   2                  9
# 41   2474111       67             5                   3                 14
# 42   1568481       67             6                   3                 12
# 43   2048527       67             8                   2                 11
# 44   2389031       67             9                   2                 14
# 45   2378562       67            10                   1                 10
# 46   1515698       67            11                   1                 11
# 47   1928050       67            12                   2                 12
# 48   1949274       67            13                   1                 10
# 49    551869       67            14                   1                  9
# 50    768572       67            16                   4                 10
# 51    150528       67            18                   5                 16
# 52     29758       67            19                   0                 14
# 53   1558976       67            21                   1                  9
# 54    863974       67            22                   1                 11
# 55   2308399       67            23                   1                 14
# 56   2759128       81             3                   1                  9
# 57   1812985       81             5                   2                 20
# 58   1889835       82             1                   3                 15
# 59    499460       82             3                   5                 10
#
#     days_since_last_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
# 5                    19.0         196                  1          1
# 6                    20.0         196                  1          1
# 7                    14.0         196                  2          1
# 8                     0.0         196                  4          1
# 9                    30.0         196                  1          1
# 10                    7.0         196                  2          0
# 11                    8.0         196                  6          1
# 12                    7.0         196                  1          1
# 13                    7.0         196                  1          1
# 14                   14.0         196                  1          1
# 15                    6.0         196                  3          0
# 16                    8.0         196                 15          1
# 17                    6.0         196                  1          1
# 18                    6.0         196                  2          0
# 19                    7.0         196                 17          0
# 20                    8.0         196                 14          1
# 21                    4.0         196                  9          0
# 22                    3.0         196                  1          1
# 23                    NaN         196                  4          0
# 24                    7.0         196                  5          1
# 25                    7.0         196                  3          1
# 26                    8.0         196                  6          1
# 27                    8.0         196                  5          1
# 28                    7.0         196                  5          1
# 29                    8.0         196                  4          1
# 30                    7.0         196                  3          1
# 31                    6.0         196                  7          1
# 32                    8.0         196                  3          1
# 33                    6.0         196                  4          1
# 34                   14.0         196                  6          1
# 35                    8.0         196                  4          1
# 36                   30.0         196                  1          1
# 37                    NaN         196                  1          0
# 38                    5.0         196                  2          1
# 39                    7.0         196                  2          1
# 40                    8.0         196                  1          1
# 41                    8.0         196                  2          1
# 42                    7.0         196                  2          1
# 43                    7.0         196                  1          1
# 44                    7.0         196                  1          1
# 45                    6.0         196                  1          1
# 46                    7.0         196                  1          1
# 47                    8.0         196                  1          1
# 48                    6.0         196                  1          1
# 49                    7.0         196                  1          1
# 50                    9.0         196                  1          1
# 51                    4.0         196                  1          1
# 52                    9.0         196                  2          1
# 53                    5.0         196                  2          1
# 54                   14.0         196                  3          1
# 55                   14.0         196                  1          1
# 56                   14.0         196                  2          0
# 57                   30.0         196                  1          1
# 58                    NaN         196                  6          0
# 59                    5.0         196                  2          1
#
#     Unnamed: 0_y  ...  price_range_loc    price_range_loc     busiest_day  \
# 0            195  ...              NaN  Mid-range product  Regularly busy
# 1            195  ...              NaN  Mid-range product  Regularly busy
# 2            195  ...              NaN  Mid-range product  Regularly busy
# 3            195  ...              NaN  Mid-range product      Least busy
# 4            195  ...              NaN  Mid-range product      Least busy
# 5            195  ...              NaN  Mid-range product  Regularly busy
# 6            195  ...              NaN  Mid-range product  Regularly busy
# 7            195  ...              NaN  Mid-range product  Regularly busy
# 8            195  ...              NaN  Mid-range product  Regularly busy
# 9            195  ...              NaN  Mid-range product      Least busy
# 10           195  ...              NaN  Mid-range product  Regularly busy
# 11           195  ...              NaN  Mid-range product  Regularly busy
# 12           195  ...              NaN  Mid-range product  Regularly busy
# 13           195  ...              NaN  Mid-range product  Regularly busy
# 14           195  ...              NaN  Mid-range product  Regularly busy
# 15           195  ...              NaN  Mid-range product  Regularly busy
# 16           195  ...              NaN  Mid-range product  Regularly busy
# 17           195  ...              NaN  Mid-range product      Least busy
# 18           195  ...              NaN  Mid-range product  Regularly busy
# 19           195  ...              NaN  Mid-range product  Regularly busy
# 20           195  ...              NaN  Mid-range product  Regularly busy
# 21           195  ...              NaN  Mid-range product      Least busy
# 22           195  ...              NaN  Mid-range product      Least busy
# 23           195  ...              NaN  Mid-range product  Regularly busy
# 24           195  ...              NaN  Mid-range product  Regularly busy
# 25           195  ...              NaN  Mid-range product  Regularly busy
# 26           195  ...              NaN  Mid-range product  Regularly busy
# 27           195  ...              NaN  Mid-range product  Regularly busy
# 28           195  ...              NaN  Mid-range product  Regularly busy
# 29           195  ...              NaN  Mid-range product  Regularly busy
# 30           195  ...              NaN  Mid-range product  Regularly busy
# 31           195  ...              NaN  Mid-range product  Regularly busy
# 32           195  ...              NaN  Mid-range product  Regularly busy
# 33           195  ...              NaN  Mid-range product  Regularly busy
# 34           195  ...              NaN  Mid-range product  Regularly busy
# 35           195  ...              NaN  Mid-range product  Regularly busy
# 36           195  ...              NaN  Mid-range product  Regularly busy
# 37           195  ...              NaN  Mid-range product  Regularly busy
# 38           195  ...              NaN  Mid-range product  Regularly busy
# 39           195  ...              NaN  Mid-range product  Regularly busy
# 40           195  ...              NaN  Mid-range product  Regularly busy
# 41           195  ...              NaN  Mid-range product  Regularly busy
# 42           195  ...              NaN  Mid-range product  Regularly busy
# 43           195  ...              NaN  Mid-range product  Regularly busy
# 44           195  ...              NaN  Mid-range product  Regularly busy
# 45           195  ...              NaN  Mid-range product  Regularly busy
# 46           195  ...              NaN  Mid-range product  Regularly busy
# 47           195  ...              NaN  Mid-range product  Regularly busy
# 48           195  ...              NaN  Mid-range product  Regularly busy
# 49           195  ...              NaN  Mid-range product  Regularly busy
# 50           195  ...              NaN  Mid-range product      Least busy
# 51           195  ...              NaN  Mid-range product  Regularly busy
# 52           195  ...              NaN  Mid-range product     Busiest day
# 53           195  ...              NaN  Mid-range product  Regularly busy
# 54           195  ...              NaN  Mid-range product  Regularly busy
# 55           195  ...              NaN  Mid-range product  Regularly busy
# 56           195  ...              NaN  Mid-range product  Regularly busy
# 57           195  ...              NaN  Mid-range product  Regularly busy
# 58           195  ...              NaN  Mid-range product  Regularly busy
# 59           195  ...              NaN  Mid-range product  Regularly busy
#
#        busiest_days busiest_period_of_day max_order      loyalty_flag  \
# 0    Regularly busy        Average orders        10      New customer
# 1   Least busy days        Average orders        10      New customer
# 2   Least busy days           Most orders        10      New customer
# 3   Least busy days        Average orders        10      New customer
# 4   Least busy days           Most orders        10      New customer
# 5    Regularly busy        Average orders        10      New customer
# 6      Busiest days           Most orders        10      New customer
# 7      Busiest days           Most orders        10      New customer
# 8      Busiest days           Most orders        10      New customer
# 9   Least busy days        Average orders        10      New customer
# 10     Busiest days           Most orders        22  Regular customer
# 11   Regularly busy           Most orders        22  Regular customer
# 12   Regularly busy           Most orders        22  Regular customer
# 13     Busiest days           Most orders        22  Regular customer
# 14     Busiest days           Most orders        22  Regular customer
# 15   Regularly busy           Most orders         9      New customer
# 16   Regularly busy           Most orders         9      New customer
# 17  Least busy days        Average orders         9      New customer
# 18  Least busy days           Most orders        33  Regular customer
# 19  Least busy days        Average orders        20  Regular customer
# 20  Least busy days           Most orders        20  Regular customer
# 21  Least busy days           Most orders        11  Regular customer
# 22  Least busy days           Most orders        11  Regular customer
# 23     Busiest days           Most orders        27  Regular customer
# 24     Busiest days           Most orders        27  Regular customer
# 25     Busiest days           Most orders        27  Regular customer
# 26   Regularly busy           Most orders        27  Regular customer
# 27   Regularly busy        Average orders        27  Regular customer
# 28     Busiest days           Most orders        27  Regular customer
# 29   Regularly busy           Most orders        27  Regular customer
# 30   Regularly busy           Most orders        27  Regular customer
# 31     Busiest days           Most orders        27  Regular customer
# 32   Regularly busy           Most orders        27  Regular customer
# 33   Regularly busy           Most orders        27  Regular customer
# 34   Regularly busy           Most orders        27  Regular customer
# 35  Least busy days        Average orders        27  Regular customer
# 36   Regularly busy           Most orders        27  Regular customer
# 37  Least busy days           Most orders        24  Regular customer
# 38     Busiest days           Most orders        24  Regular customer
# 39     Busiest days           Most orders        24  Regular customer
# 40   Regularly busy           Most orders        24  Regular customer
# 41  Least busy days           Most orders        24  Regular customer
# 42  Least busy days           Most orders        24  Regular customer
# 43   Regularly busy           Most orders        24  Regular customer
# 44   Regularly busy           Most orders        24  Regular customer
# 45     Busiest days           Most orders        24  Regular customer
# 46     Busiest days           Most orders        24  Regular customer
# 47   Regularly busy           Most orders        24  Regular customer
# 48     Busiest days           Most orders        24  Regular customer
# 49     Busiest days           Most orders        24  Regular customer
# 50  Least busy days           Most orders        24  Regular customer
# 51   Regularly busy           Most orders        24  Regular customer
# 52     Busiest days           Most orders        24  Regular customer
# 53     Busiest days           Most orders        24  Regular customer
# 54     Busiest days           Most orders        24  Regular customer
# 55     Busiest days           Most orders        24  Regular customer
# 56     Busiest days           Most orders         7      New customer
# 57   Regularly busy        Average orders         7      New customer
# 58  Least busy days           Most orders        19  Regular customer
# 59   Regularly busy           Most orders        19  Regular customer
#
#    average_price spending_flag median_prior_orders
# 0       6.367797   Low Spender                20.5
# 1       6.367797   Low Spender                20.5
# 2       6.367797   Low Spender                20.5
# 3       6.367797   Low Spender                20.5
# 4       6.367797   Low Spender                20.5
# 5       6.367797   Low Spender                20.5
# 6       6.367797   Low Spender                20.5
# 7       6.367797   Low Spender                20.5
# 8       6.367797   Low Spender                20.5
# 9       6.367797   Low Spender                20.5
# 10      3.980556   Low Spender                10.0
# 11      3.980556   Low Spender                10.0
# 12      3.980556   Low Spender                10.0
# 13      3.980556   Low Spender                10.0
# 14      3.980556   Low Spender                10.0
# 15      8.372059   Low Spender                 6.0
# 16      8.372059   Low Spender                 6.0
# 17      8.372059   Low Spender                 6.0
# 18      7.012683   Low Spender                 7.5
# 19      8.137793   Low Spender                 6.0
# 20      8.137793   Low Spender                 6.0
# 21      7.444898   Low Spender                10.0
# 22      7.444898   Low Spender                10.0
# 23      6.408876   Low Spender                 8.0
# 24      6.408876   Low Spender                 8.0
# 25      6.408876   Low Spender                 8.0
# 26      6.408876   Low Spender                 8.0
# 27      6.408876   Low Spender                 8.0
# 28      6.408876   Low Spender                 8.0
# 29      6.408876   Low Spender                 8.0
# 30      6.408876   Low Spender                 8.0
# 31      6.408876   Low Spender                 8.0
# 32      6.408876   Low Spender                 8.0
# 33      6.408876   Low Spender                 8.0
# 34      6.408876   Low Spender                 8.0
# 35      6.408876   Low Spender                 8.0
# 36      6.408876   Low Spender                 8.0
# 37      7.656790   Low Spender                 7.0
# 38      7.656790   Low Spender                 7.0
# 39      7.656790   Low Spender                 7.0
# 40      7.656790   Low Spender                 7.0
# 41      7.656790   Low Spender                 7.0
# 42      7.656790   Low Spender                 7.0
# 43      7.656790   Low Spender                 7.0
# 44      7.656790   Low Spender                 7.0
# 45      7.656790   Low Spender                 7.0
# 46      7.656790   Low Spender                 7.0
# 47      7.656790   Low Spender                 7.0
# 48      7.656790   Low Spender                 7.0
# 49      7.656790   Low Spender                 7.0
# 50      7.656790   Low Spender                 7.0
# 51      7.656790   Low Spender                 7.0
# 52      7.656790   Low Spender                 7.0
# 53      7.656790   Low Spender                 7.0
# 54      7.656790   Low Spender                 7.0
# 55      7.656790   Low Spender                 7.0
# 56      8.262963   Low Spender                30.0
# 57      8.262963   Low Spender                30.0
# 58      6.441221   Low Spender                11.5
# 59      6.441221   Low Spender                11.5
#
# [60 rows x 25 columns]

# %%
#Set criteria with loc()
ords_prods_merge.loc[ords_prods_merge['median_prior_orders'] > 20, 'frequency_flag'] = 'Non-frequent Customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['median_prior_orders'] > 10) & (ords_prods_merge['median_prior_orders'] <= 20), 'frequency_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['median_prior_orders'] <= 10, 'frequency_flag'] = 'Frequent Customer'

# %%
#Check value counts
ords_prods_merge['frequency_flag'].value_counts(dropna = False)
# Out:
# Frequent Customer        21577409
# Regular customer          7217134
# Non-frequent Customer     3639669
# Name: frequency_flag, dtype: int64

# %% [markdown]
# ## Step 9 - Export as Pickle File

# %%
ords_prods_merge.to_pickle(os.path.join(path, '02 Data', 'Prepared Data','orders_products_merged_flags_v2.pkl'))
