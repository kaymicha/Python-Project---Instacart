# %% [markdown]
# # Task 4.8 - Grouping Data & Aggregating Variables

# %% [markdown]
# ## Step 1 - import libraries & dataframe

# %%
# Import Libraries
import pandas as pd
import numpy as np
import os

# %%
# Defining path
path = r'C:\Users\kaymi\OneDrive\Documents\05-2023-Instacart Basket Analysis'

# %%
# Import ords_prods_merged
ords_prods_merge =  pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data','orders_products_merged_updated.pkl'))

# %%
# Check columns
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#   days_since_last_order  product_id  add_to_cart_order  reordered  \
# 0           first order         196                  1          0
# 1                  15.0         196                  1          1
# 2                  21.0         196                  1          1
# 3                  29.0         196                  1          1
# 4                  28.0         196                  1          1
#
#    Unnamed: 0_y product_name  aisle_id  department_id  prices _merge  \
# 0           195         Soda        77              7     9.0   both
# 1           195         Soda        77              7     9.0   both
# 2           195         Soda        77              7     9.0   both
# 3           195         Soda        77              7     9.0   both
# 4           195         Soda        77              7     9.0   both
#
#    price_range_loc    price_range_loc     busiest_day     busiest_days  \
# 0              NaN  Mid-range product  Regularly busy   Regularly busy
# 1              NaN  Mid-range product  Regularly busy  Least busy days
# 2              NaN  Mid-range product  Regularly busy  Least busy days
# 3              NaN  Mid-range product      Least busy  Least busy days
# 4              NaN  Mid-range product      Least busy  Least busy days
#
#   busiest_period_of_day
# 0        Average orders
# 1        Average orders
# 2           Most orders
# 3        Average orders
# 4           Most orders

# %% [markdown]
# ## Step 2 - Find aggregated mean of entire dataframe

# %%
# Group by Department ID
ords_prods_merge.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.457687
# 2                17.277920
# 3                17.179756
# 4                17.811403
# 5                15.213779
# 6                16.439806
# 7                17.225773
# 8                15.340520
# 9                15.895474
# 10               20.197148
# 11               16.170828
# 12               15.887622
# 13               16.583304
# 14               16.757377
# 15               16.165037
# 16               17.663250
# 17               15.694469
# 18               19.310397
# 19               17.177343
# 20               16.473447
# 21               22.902379

# %% [markdown]
# ## Step 3 - Analyze the results - compare to those of the subset

# %% [markdown]
# ##### In the subset, only a handful of departments were displayed due to the limited number of rows pulled. On average, the mean of each department ID in the entire dataframe is lower than that of the subset.

# %% [markdown]
# ## Step 4 - Follow the Exercise instructions for creating a loyalty flag

# %%
# split the data into groups based on user_id column, apply the transform() function on the "order_number" column, and create a new max_order column
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
# Check column was created
ords_prods_merge.head(15)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2398795        1             2                   3                  7
# 2     473747        1             3                   3                 12
# 3    2254736        1             4                   4                  7
# 4     431534        1             5                   4                 15
# 5    3367565        1             6                   2                  7
# 6     550135        1             7                   1                  9
# 7    3108588        1             8                   1                 14
# 8    2295261        1             9                   1                 16
# 9    2550362        1            10                   4                  8
# 10   2968173       15            15                   1                  9
# 11   1870022       15            17                   2                 16
# 12   1911383       15            18                   2                 11
# 13   2715276       15            21                   1                  9
# 14    487368       15            22                   1                 10
#
#    days_since_last_order  product_id  add_to_cart_order  reordered  \
# 0            first order         196                  1          0
# 1                   15.0         196                  1          1
# 2                   21.0         196                  1          1
# 3                   29.0         196                  1          1
# 4                   28.0         196                  1          1
# 5                   19.0         196                  1          1
# 6                   20.0         196                  1          1
# 7                   14.0         196                  2          1
# 8                    0.0         196                  4          1
# 9                   30.0         196                  1          1
# 10                   7.0         196                  2          0
# 11                   8.0         196                  6          1
# 12                   7.0         196                  1          1
# 13                   7.0         196                  1          1
# 14                  14.0         196                  1          1
#
#     Unnamed: 0_y  ... aisle_id  department_id  prices  _merge  \
# 0            195  ...       77              7     9.0    both
# 1            195  ...       77              7     9.0    both
# 2            195  ...       77              7     9.0    both
# 3            195  ...       77              7     9.0    both
# 4            195  ...       77              7     9.0    both
# 5            195  ...       77              7     9.0    both
# 6            195  ...       77              7     9.0    both
# 7            195  ...       77              7     9.0    both
# 8            195  ...       77              7     9.0    both
# 9            195  ...       77              7     9.0    both
# 10           195  ...       77              7     9.0    both
# 11           195  ...       77              7     9.0    both
# 12           195  ...       77              7     9.0    both
# 13           195  ...       77              7     9.0    both
# 14           195  ...       77              7     9.0    both
#
#     price_range_loc    price_range_loc     busiest_day     busiest_days  \
# 0               NaN  Mid-range product  Regularly busy   Regularly busy
# 1               NaN  Mid-range product  Regularly busy  Least busy days
# 2               NaN  Mid-range product  Regularly busy  Least busy days
# 3               NaN  Mid-range product      Least busy  Least busy days
# 4               NaN  Mid-range product      Least busy  Least busy days
# 5               NaN  Mid-range product  Regularly busy   Regularly busy
# 6               NaN  Mid-range product  Regularly busy     Busiest days
# 7               NaN  Mid-range product  Regularly busy     Busiest days
# 8               NaN  Mid-range product  Regularly busy     Busiest days
# 9               NaN  Mid-range product      Least busy  Least busy days
# 10              NaN  Mid-range product  Regularly busy     Busiest days
# 11              NaN  Mid-range product  Regularly busy   Regularly busy
# 12              NaN  Mid-range product  Regularly busy   Regularly busy
# 13              NaN  Mid-range product  Regularly busy     Busiest days
# 14              NaN  Mid-range product  Regularly busy     Busiest days
#
#    busiest_period_of_day max_order
# 0         Average orders        10
# 1         Average orders        10
# 2            Most orders        10
# 3         Average orders        10
# 4            Most orders        10
# 5         Average orders        10
# 6            Most orders        10
# 7            Most orders        10
# 8            Most orders        10
# 9         Average orders        10
# 10           Most orders        22
# 11           Most orders        22
# 12           Most orders        22
# 13           Most orders        22
# 14           Most orders        22
#
# [15 rows x 21 columns]

# %%
# Derive columns with loc()
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
# Check value counts
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15891077
# Loyal customer      10293737
# New customer         6249398
# Name: loyalty_flag, dtype: int64

# %%
# Return only columns desired
ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      New customer             1
# 1         1      New customer             2
# 2         1      New customer             3
# 3         1      New customer             4
# 4         1      New customer             5
# 5         1      New customer             6
# 6         1      New customer             7
# 7         1      New customer             8
# 8         1      New customer             9
# 9         1      New customer            10
# 10       15  Regular customer            15
# 11       15  Regular customer            17
# 12       15  Regular customer            18
# 13       15  Regular customer            21
# 14       15  Regular customer            22
# 15       19      New customer             2
# 16       19      New customer             5
# 17       19      New customer             7
# 18       21  Regular customer            10
# 19       31  Regular customer            10
# 20       31  Regular customer            17
# 21       43  Regular customer             6
# 22       43  Regular customer             9
# 23       52  Regular customer             1
# 24       52  Regular customer             2
# 25       52  Regular customer             3
# 26       52  Regular customer             5
# 27       52  Regular customer             7
# 28       52  Regular customer             9
# 29       52  Regular customer            10
# 30       52  Regular customer            11
# 31       52  Regular customer            12
# 32       52  Regular customer            15
# 33       52  Regular customer            17
# 34       52  Regular customer            18
# 35       52  Regular customer            19
# 36       52  Regular customer            21
# 37       67  Regular customer             1
# 38       67  Regular customer             2
# 39       67  Regular customer             3
# 40       67  Regular customer             4
# 41       67  Regular customer             5
# 42       67  Regular customer             6
# 43       67  Regular customer             8
# 44       67  Regular customer             9
# 45       67  Regular customer            10
# 46       67  Regular customer            11
# 47       67  Regular customer            12
# 48       67  Regular customer            13
# 49       67  Regular customer            14
# 50       67  Regular customer            16
# 51       67  Regular customer            18
# 52       67  Regular customer            19
# 53       67  Regular customer            21
# 54       67  Regular customer            22
# 55       67  Regular customer            23
# 56       81      New customer             3
# 57       81      New customer             5
# 58       82  Regular customer             1
# 59       82  Regular customer             3

# %% [markdown]
# ## Step 5 - Use loyalty flag for analysis

# %%
#Check basic statistics
ords_prods_merge.groupby('loyalty_flag').agg({'prices': ['mean', 'min', 'max']})
# Out:
#                     prices
#                       mean  min   max
# loyalty_flag
# Loyal customer    7.778412  1.0  25.0
# New customer      7.805500  1.0  25.0
# Regular customer  7.802850  1.0  25.0

# %% [markdown]
# #### It seems that on average, loyal customers purchase products that cost slightly less than what new and regular customers purchase.

# %% [markdown]
# ## Step 6 - Create a spending flag based on average price of orders per user

# %%
#Group data on user_id column, apply the transform() function on the "prices" column, and create a new spending column
ords_prods_merge['average_price'] = ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)

# %%
# Check column was created
ords_prods_merge.head(15)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2398795        1             2                   3                  7
# 2     473747        1             3                   3                 12
# 3    2254736        1             4                   4                  7
# 4     431534        1             5                   4                 15
# 5    3367565        1             6                   2                  7
# 6     550135        1             7                   1                  9
# 7    3108588        1             8                   1                 14
# 8    2295261        1             9                   1                 16
# 9    2550362        1            10                   4                  8
# 10   2968173       15            15                   1                  9
# 11   1870022       15            17                   2                 16
# 12   1911383       15            18                   2                 11
# 13   2715276       15            21                   1                  9
# 14    487368       15            22                   1                 10
#
#    days_since_last_order  product_id  add_to_cart_order  reordered  \
# 0            first order         196                  1          0
# 1                   15.0         196                  1          1
# 2                   21.0         196                  1          1
# 3                   29.0         196                  1          1
# 4                   28.0         196                  1          1
# 5                   19.0         196                  1          1
# 6                   20.0         196                  1          1
# 7                   14.0         196                  2          1
# 8                    0.0         196                  4          1
# 9                   30.0         196                  1          1
# 10                   7.0         196                  2          0
# 11                   8.0         196                  6          1
# 12                   7.0         196                  1          1
# 13                   7.0         196                  1          1
# 14                  14.0         196                  1          1
#
#     Unnamed: 0_y  ... prices  _merge   price_range_loc    price_range_loc  \
# 0            195  ...    9.0    both               NaN  Mid-range product
# 1            195  ...    9.0    both               NaN  Mid-range product
# 2            195  ...    9.0    both               NaN  Mid-range product
# 3            195  ...    9.0    both               NaN  Mid-range product
# 4            195  ...    9.0    both               NaN  Mid-range product
# 5            195  ...    9.0    both               NaN  Mid-range product
# 6            195  ...    9.0    both               NaN  Mid-range product
# 7            195  ...    9.0    both               NaN  Mid-range product
# 8            195  ...    9.0    both               NaN  Mid-range product
# 9            195  ...    9.0    both               NaN  Mid-range product
# 10           195  ...    9.0    both               NaN  Mid-range product
# 11           195  ...    9.0    both               NaN  Mid-range product
# 12           195  ...    9.0    both               NaN  Mid-range product
# 13           195  ...    9.0    both               NaN  Mid-range product
# 14           195  ...    9.0    both               NaN  Mid-range product
#
#        busiest_day     busiest_days busiest_period_of_day max_order  \
# 0   Regularly busy   Regularly busy        Average orders        10
# 1   Regularly busy  Least busy days        Average orders        10
# 2   Regularly busy  Least busy days           Most orders        10
# 3       Least busy  Least busy days        Average orders        10
# 4       Least busy  Least busy days           Most orders        10
# 5   Regularly busy   Regularly busy        Average orders        10
# 6   Regularly busy     Busiest days           Most orders        10
# 7   Regularly busy     Busiest days           Most orders        10
# 8   Regularly busy     Busiest days           Most orders        10
# 9       Least busy  Least busy days        Average orders        10
# 10  Regularly busy     Busiest days           Most orders        22
# 11  Regularly busy   Regularly busy           Most orders        22
# 12  Regularly busy   Regularly busy           Most orders        22
# 13  Regularly busy     Busiest days           Most orders        22
# 14  Regularly busy     Busiest days           Most orders        22
#
#         loyalty_flag average_price
# 0       New customer      6.367797
# 1       New customer      6.367797
# 2       New customer      6.367797
# 3       New customer      6.367797
# 4       New customer      6.367797
# 5       New customer      6.367797
# 6       New customer      6.367797
# 7       New customer      6.367797
# 8       New customer      6.367797
# 9       New customer      6.367797
# 10  Regular customer      3.980556
# 11  Regular customer      3.980556
# 12  Regular customer      3.980556
# 13  Regular customer      3.980556
# 14  Regular customer      3.980556
#
# [15 rows x 23 columns]

# %%
# Derive columns with loc()
ords_prods_merge.loc[ords_prods_merge['average_price'] >= 10, 'spending_flag'] = 'High Spender'

# %%
ords_prods_merge.loc[ords_prods_merge['average_price'] < 10, 'spending_flag'] = 'Low Spender'

# %%
# Check value counts
ords_prods_merge['spending_flag'].value_counts(dropna = False)
# Out:
# Low Spender     32313511
# High Spender      120701
# Name: spending_flag, dtype: int64

# %%
# Return only columns desired
ords_prods_merge[['user_id', 'spending_flag', 'prices']].head(20)
# Out:
#     user_id spending_flag  prices
# 0         1   Low Spender     9.0
# 1         1   Low Spender     9.0
# 2         1   Low Spender     9.0
# 3         1   Low Spender     9.0
# 4         1   Low Spender     9.0
# 5         1   Low Spender     9.0
# 6         1   Low Spender     9.0
# 7         1   Low Spender     9.0
# 8         1   Low Spender     9.0
# 9         1   Low Spender     9.0
# 10       15   Low Spender     9.0
# 11       15   Low Spender     9.0
# 12       15   Low Spender     9.0
# 13       15   Low Spender     9.0
# 14       15   Low Spender     9.0
# 15       19   Low Spender     9.0
# 16       19   Low Spender     9.0
# 17       19   Low Spender     9.0
# 18       21   Low Spender     9.0
# 19       31   Low Spender     9.0

# %% [markdown]
# #### There are significantly more low spenders than high spenders using Instacart's criteria of low versus high spenders

# %% [markdown]
# ## Step 7 - Create order frequency flag using median in days_since_prior_order column grouped by user_id

# %%
# Find and replace "first order" with "0"
ords_prods_merge.replace(to_replace=['first order'],value = 0)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[28], line 2
#       1 # Find and replace "first order" with "0"
# ----> 2 ords_prods_merge.replace(to_replace=['first order'],value = 0)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:5728, in DataFrame.replace(self, to_replace, value, inplace, limit, regex, method)
#    5715 @deprecate_nonkeyword_arguments(
#    5716     version=None, allowed_args=["self", "to_replace", "value"]
#    5717 )
#    (...)
#    5726     method: Literal["pad", "ffill", "bfill"] | lib.NoDefault = lib.no_default,
#    5727 ) -> DataFrame | None:
# -> 5728     return super().replace(
#    5729         to_replace=to_replace,
#    5730         value=value,
#    5731         inplace=inplace,
#    5732         limit=limit,
#    5733         regex=regex,
#    5734         method=method,
#    5735     )
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:7237, in NDFrame.replace(self, to_replace, value, inplace, limit, regex, method)
#    7232     if len(to_replace) != len(value):
#    7233         raise ValueError(
#    7234             f"Replacement lists must match in length. "
#    7235             f"Expecting {len(to_replace)} got {len(value)} "
#    7236         )
# -> 7237     new_data = self._mgr.replace_list(
#    7238         src_list=to_replace,
#    7239         dest_list=value,
#    7240         inplace=inplace,
#    7241         regex=regex,
#    7242     )
#    7244 elif to_replace is None:
#    7245     if not (
#    7246         is_re_compilable(regex)
#    7247         or is_list_like(regex)
#    7248         or is_dict_like(regex)
#    7249     ):
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py:487, in BaseBlockManager.replace_list(self, src_list, dest_list, inplace, regex)
#     484 """do a list replace"""
#     485 inplace = validate_bool_kwarg(inplace, "inplace")
# --> 487 bm = self.apply(
#     488     "replace_list",
#     489     src_list=src_list,
#     490     dest_list=dest_list,
#     491     inplace=inplace,
#     492     regex=regex,
#     493 )
#     494 bm._consolidate_inplace()
#     495 return bm
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py:352, in BaseBlockManager.apply(self, f, align_keys, ignore_failures, **kwargs)
#     350         applied = b.apply(f, **kwargs)
#     351     else:
# --> 352         applied = getattr(b, f)(**kwargs)
#     353 except (TypeError, NotImplementedError):
#     354     if not ignore_failures:
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:697, in Block.replace_list(self, src_list, dest_list, inplace, regex)
#     692 pairs = [
#     693     (x, y) for x, y in zip(src_list, dest_list) if self._can_hold_element(x)
#     694 ]
#     695 if not len(pairs):
#     696     # shortcut, nothing to replace
# --> 697     return [self] if inplace else [self.copy()]
#     699 src_len = len(pairs) - 1
#     701 if is_string_dtype(values.dtype):
#     702     # Calculate the mask once, prior to the call of comp
#     703     # in order to avoid repeating the same computations
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:549, in Block.copy(self, deep)
#     547 values = self.values
#     548 if deep:
# --> 549     values = values.copy()
#     550 return type(self)(values, placement=self._mgr_locs, ndim=self.ndim)
#
# MemoryError: Unable to allocate 495. MiB for an array with shape (2, 32434212) and data type float64

# %%
# Check data type of column
ords_prods_merge['days_since_last_order'].dtype
# Out:
# dtype('O')

# %%
# Data type is set as String - Change to Number
ords_prods_merge['days_since_last_order'] = ords_prods_merge['days_since_last_order'].astype('float')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 2
#       1 # Data type is set as String - Change to Number
# ----> 2 ords_prods_merge['days_since_last_order'] = ords_prods_merge['days_since_last_order'].astype('float')
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py:448, in BaseBlockManager.astype(self, dtype, copy, errors)
#     447 def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 448     return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py:352, in BaseBlockManager.apply(self, f, align_keys, ignore_failures, **kwargs)
#     350         applied = b.apply(f, **kwargs)
#     351     else:
# --> 352         applied = getattr(b, f)(**kwargs)
#     353 except (TypeError, NotImplementedError):
#     354     if not ignore_failures:
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:526, in Block.astype(self, dtype, copy, errors)
#     508 """
#     509 Coerce to the new dtype.
#     510
#    (...)
#     522 Block
#     523 """
#     524 values = self.values
# --> 526 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     528 new_values = maybe_coerce_values(new_values)
#     529 newb = self.make_block(new_values)
#
# File ~\anaconda3\lib\site-packages\pandas\core\dtypes\astype.py:299, in astype_array_safe(values, dtype, copy, errors)
#     296     return values.copy()
#     298 try:
# --> 299     new_values = astype_array(values, dtype, copy=copy)
#     300 except (ValueError, TypeError):
#     301     # e.g. astype_nansafe can fail on object-dtype of strings
#     302     #  trying to convert to float
#     303     if errors == "ignore":
#
# File ~\anaconda3\lib\site-packages\pandas\core\dtypes\astype.py:230, in astype_array(values, dtype, copy)
#     227     values = values.astype(dtype, copy=copy)
#     229 else:
# --> 230     values = astype_nansafe(values, dtype, copy=copy)
#     232 # in pandas we don't store numpy str dtypes, so convert to object
#     233 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~\anaconda3\lib\site-packages\pandas\core\dtypes\astype.py:170, in astype_nansafe(arr, dtype, copy, skipna)
#     166     raise ValueError(msg)
#     168 if copy or is_object_dtype(arr.dtype) or is_object_dtype(dtype):
#     169     # Explicit copy, or required since NumPy can't view from / to object.
# --> 170     return arr.astype(dtype, copy=True)
#     172 return arr.astype(dtype, copy=copy)
#
# ValueError: could not convert string to float: 'first order'

# %%
# Re-check data type of days since last order column
ords_prods_merge['days_since_last_order'].dtype

# %%
#Re-run group/transform function
ords_prods_merge['median_prior_orders'] = ords_prods_merge.groupby(['user_id'])['days_since_last_order'].transform(np.median)

# %%
# Check column was created
ords_prods_merge.head(15)

# %%
# Set criteria with loc()
ords_prods_merge.loc[ords_prods_merge['median_prior_orders'] > 20, 'frequency_flag'] = 'Non-Frequent Customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['median_prior_orders'] > 10) & (ords_prods_merge['median_prior_orders'] <= 20), 'frequency_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['median_prior_orders'] <= 10, 'frequency_flag'] = 'Frequent Customer'

# %%
#Check value counts
ords_prods_merge['frequency_flag'].value_counts(dropna = False)

# %%
ords_prods_merge.head(60)

# %% [markdown]
# ## Step 9 - Export as pickle file

# %%
ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged_flags.pkl'))
